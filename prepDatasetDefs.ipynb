# %%
import json
import requests

# %%
dataset_id = "NM_17"
url = f"https://www.nomisweb.co.uk/api/v01/dataset/{dataset_id}.def.sdmx.json"
req = requests.get(url)
data = req.json()

# %%
url=f"https://www.nomisweb.co.uk/api/v01/dataset/{dataset_id}/item.def.sdmx.json"
req = requests.get(url)
data = req.json()

# %%
data
# Out:
# {'structure': {'codelists': None,
#   'header': {'id': 'NM_1_1',
#    'prepared': '2024-04-29T18:02:02Z',
#    'sender': {'contact': {'email': 'support@nomisweb.co.uk',
#      'name': 'Nomis',
#      'telephone': '+44(0) 191 3342680',
#      'uri': 'https://www.nomisweb.co.uk'},
#     'id': 'NOMIS'},
#    'test': 'false'},
#   'xmlns': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message',
#   'common': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common',
#   'structure': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure',
#   'xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#   'schemalocation': 'http://sdmx.org/docs/2_0/SDMXMessage.xsd'}}

# %%
def get_dimensions(dataset_id):
    url = f"https://www.nomisweb.co.uk/api/v01/dataset/{dataset_id}.def.sdmx.json"
    req = requests.get(url)
    data = req.json()
    return data['structure']['keyfamilies']['keyfamily'][0]['components']['dimension']

# %%
def get_code_list_options(code_list_id):
    url = f'https://www.nomisweb.co.uk/api/v01/codelist/{code_list_id}.def.sdmx.json'
    print(url)
    
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raises a HTTPError for bad responses
        
        data = response.json()

        # Navigate the response object to extract the code list options
        # Assuming the code list options are located in a structure similar to your previous response
        codes = data.get('structure', {}).get('codelists', {}).get('codelist', [{}])[0].get('code', [])
        
        # Parse into a JSON list
        options_list = [{
            'code': code.get('value'),
            'description': code.get('description', {}).get('#text', '') or code.get('description')
        } for code in codes]
        
        return options_list
    except requests.RequestException as error:
        print(f'Could not get code list options: {error}')
        return []  # Return an empty array in case of an error

# %%
def get_dimension_values(codeListId):
    url = 'https://www.nomisweb.co.uk/api/v01/codelist/{codeListId}.def.sdmx.json';
    req = requests.get(url)
    data = req.json()
    return data['structure']['codelists']['codelist'][dimension_id]['code']

# %%
dataset_id = "NM_1_1"
dimensions = get_dimensions(dataset_id)
dimension_values = {}
for dimension in dimensions:
    code_list_id = dimension['codelist']
    dimension_values[dimension['conceptref']] = get_code_list_options(code_list_id)
# Out:
# https://www.nomisweb.co.uk/api/v01/codelist/CL_1_1_GEOGRAPHY.def.sdmx.json
# https://www.nomisweb.co.uk/api/v01/codelist/CL_1_1_SEX.def.sdmx.json
# https://www.nomisweb.co.uk/api/v01/codelist/CL_1_1_ITEM.def.sdmx.json
# https://www.nomisweb.co.uk/api/v01/codelist/CL_1_1_MEASURES.def.sdmx.json
# https://www.nomisweb.co.uk/api/v01/codelist/CL_1_1_FREQ.def.sdmx.json

# %%
dimension_values['VARIABLE']
# Out:
# [{'code': 1,
#   'description': {'value': '% of all people aged 16+ who are male',
#    'lang': 'en'}},
#  {'code': 2,
#   'description': {'value': '% of all people aged 16+ who are female',
#    'lang': 'en'}},
#  {'code': 3,
#   'description': {'value': '% of all people aged 16+ who are aged 16-64',
#    'lang': 'en'}},
#  {'code': 4,
#   'description': {'value': '% of males aged 16+ who are aged 16-64',
#    'lang': 'en'}},
#  {'code': 5,
#   'description': {'value': '% of females aged 16+ who are aged 16-64',
#    'lang': 'en'}},
#  {'code': 6,
#   'description': {'value': '% of aged 16-64 who are male', 'lang': 'en'}},
#  {'code': 7,
#   'description': {'value': '% of aged 16-64 who are female', 'lang': 'en'}},
#  {'code': 8,
#   'description': {'value': '% of all 16+ who are aged 16-19', 'lang': 'en'}},
#  {'code': 9,
#   'description': {'value': '% of all 16+ who are aged 20-24', 'lang': 'en'}},
#  {'code': 10,
#   'description': {'value': '% of all 16+ who are aged 25-34', 'lang': 'en'}},
#  {'code': 11,
#   'description': {'value': '% of all 16+ who are aged 35-49', 'lang': 'en'}},
#  {'code': 12,
#   'description': {'value': '% of all 16+ who are aged 50-64', 'lang': 'en'}},
#  {'code': 13,
#   'description': {'value': '% of all 16+ who are aged 65+', 'lang': 'en'}},
#  {'code': 14,
#   'description': {'value': '% of all 16+ who are aged 16-24', 'lang': 'en'}},
#  {'code': 15,
#   'description': {'value': '% of all 16+ who are aged 25-49', 'lang': 'en'}},
#  {'code': 16,
#   'description': {'value': '% of all 16+ who are aged 50+', 'lang': 'en'}},
#  {'code': 17,
#   'description': {'value': 'Economic activity rate - aged 16+', 'lang': 'en'}},
#  {'code': 18,
#   'description': {'value': 'Economic activity rate - aged 16-64',
#    'lang': 'en'}},
#  {'code': 19,
#   'description': {'value': 'Economic activity rate - aged 16-19',
#    'lang': 'en'}},
#  {'code': 20,
#   'description': {'value': 'Economic activity rate - aged 20-24',
#    'lang': 'en'}},
#  {'code': 21,
#   'description': {'value': 'Economic activity rate - aged 25-34',
#    'lang': 'en'}},
#  {'code': 22,
#   'description': {'value': 'Economic activity rate - aged 35-49',
#    'lang': 'en'}},
#  {'code': 23,
#   'description': {'value': 'Economic activity rate - aged 50+', 'lang': 'en'}},
#  {'code': 24,
#   'description': {'value': 'Economic activity rate - aged 50-64',
#    'lang': 'en'}},
#  {'code': 25,
#   'description': {'value': 'Economic activity rate - aged 65+', 'lang': 'en'}},
#  {'code': 26,
#   'description': {'value': 'Economic activity rate males - aged 16+',
#    'lang': 'en'}},
#  {'code': 27,
#   'description': {'value': 'Economic activity rate males - aged 16-64',
#    'lang': 'en'}},
#  {'code': 28,
#   'description': {'value': 'Economic activity rate males - aged 16-19',
#    'lang': 'en'}},
#  {'code': 29,
#   'description': {'value': 'Economic activity rate males - aged 20-24',
#    'lang': 'en'}},
#  {'code': 30,
#   'description': {'value': 'Economic activity rate males - aged 25-34',
#    'lang': 'en'}},
#  {'code': 31,
#   'description': {'value': 'Economic activity rate males - aged 35-49',
#    'lang': 'en'}},
#  {'code': 32,
#   'description': {'value': 'Economic activity rate males - aged 50+',
#    'lang': 'en'}},
#  {'code': 33,
#   'description': {'value': 'Economic activity rate males - aged 50-64',
#    'lang': 'en'}},
#  {'code': 34,
#   'description': {'value': 'Economic activity rate males - aged 65+',
#    'lang': 'en'}},
#  {'code': 35,
#   'description': {'value': 'Economic activity rate females - aged 16+',
#    'lang': 'en'}},
#  {'code': 36,
#   'description': {'value': 'Economic activity rate females - aged 16-64',
#    'lang': 'en'}},
#  {'code': 37,
#   'description': {'value': 'Economic activity rate females - aged 16-19',
#    'lang': 'en'}},
#  {'code': 38,
#   'description': {'value': 'Economic activity rate females - aged 20-24',
#    'lang': 'en'}},
#  {'code': 39,
#   'description': {'value': 'Economic activity rate females - aged 25-34',
#    'lang': 'en'}},
#  {'code': 40,
#   'description': {'value': 'Economic activity rate females - aged 35-49',
#    'lang': 'en'}},
#  {'code': 41,
#   'description': {'value': 'Economic activity rate females - aged 50+',
#    'lang': 'en'}},
#  {'code': 42,
#   'description': {'value': 'Economic activity rate females - aged 50-64',
#    'lang': 'en'}},
#  {'code': 43,
#   'description': {'value': 'Economic activity rate females - aged 65+',
#    'lang': 'en'}},
#  {'code': 44,
#   'description': {'value': 'Employment rate - aged 16+', 'lang': 'en'}},
#  {'code': 45,
#   'description': {'value': 'Employment rate - aged 16-64', 'lang': 'en'}},
#  {'code': 46,
#   'description': {'value': 'Employment rate - aged 16-19', 'lang': 'en'}},
#  {'code': 47,
#   'description': {'value': 'Employment rate - aged 20-24', 'lang': 'en'}},
#  {'code': 48,
#   'description': {'value': 'Employment rate - aged 25-34', 'lang': 'en'}},
#  {'code': 49,
#   'description': {'value': 'Employment rate - aged 35-49', 'lang': 'en'}},
#  {'code': 50,
#   'description': {'value': 'Employment rate - aged 50+', 'lang': 'en'}},
#  {'code': 51,
#   'description': {'value': 'Employment rate - aged 50-64', 'lang': 'en'}},
#  {'code': 52,
#   'description': {'value': 'Employment rate - aged 65+', 'lang': 'en'}},
#  {'code': 53,
#   'description': {'value': 'Employment rate males - aged 16+', 'lang': 'en'}},
#  {'code': 54,
#   'description': {'value': 'Employment rate males - aged 16-64',
#    'lang': 'en'}},
#  {'code': 55,
#   'description': {'value': 'Employment rate males - aged 16-19',
#    'lang': 'en'}},
#  {'code': 56,
#   'description': {'value': 'Employment rate males - aged 20-24',
#    'lang': 'en'}},
#  {'code': 57,
#   'description': {'value': 'Employment rate males - aged 25-34',
#    'lang': 'en'}},
#  {'code': 58,
#   'description': {'value': 'Employment rate males - aged 35-49',
#    'lang': 'en'}},
#  {'code': 59,
#   'description': {'value': 'Employment rate males - aged 50+', 'lang': 'en'}},
#  {'code': 60,
#   'description': {'value': 'Employment rate males - aged 50-64',
#    'lang': 'en'}},
#  {'code': 61,
#   'description': {'value': 'Employment rate males - aged 65+', 'lang': 'en'}},
#  {'code': 62,
#   'description': {'value': 'Employment rate females - aged 16+',
#    'lang': 'en'}},
#  {'code': 63,
#   'description': {'value': 'Employment rate females - aged 16-64',
#    'lang': 'en'}},
#  {'code': 64,
#   'description': {'value': 'Employment rate females - aged 16-19',
#    'lang': 'en'}},
#  {'code': 65,
#   'description': {'value': 'Employment rate females - aged 20-24',
#    'lang': 'en'}},
#  {'code': 66,
#   'description': {'value': 'Employment rate females - aged 25-34',
#    'lang': 'en'}},
#  {'code': 67,
#   'description': {'value': 'Employment rate females - aged 35-49',
#    'lang': 'en'}},
#  {'code': 68,
#   'description': {'value': 'Employment rate females - aged 50+',
#    'lang': 'en'}},
#  {'code': 69,
#   'description': {'value': 'Employment rate females - aged 50-64',
#    'lang': 'en'}},
#  {'code': 70,
#   'description': {'value': 'Employment rate females - aged 65+',
#    'lang': 'en'}},
#  {'code': 71,
#   'description': {'value': '% in employment who are employees - aged 16+',
#    'lang': 'en'}},
#  {'code': 72,
#   'description': {'value': '% in employment who are employees - aged 16-64',
#    'lang': 'en'}},
#  {'code': 73,
#   'description': {'value': '% in employment who are self employed - aged 16+',
#    'lang': 'en'}},
#  {'code': 74,
#   'description': {'value': '% in employment who are self employed - aged 16-64',
#    'lang': 'en'}},
#  {'code': 75,
#   'description': {'value': '% of males in employment who are employees - aged 16+',
#    'lang': 'en'}},
#  {'code': 76,
#   'description': {'value': '% of males in employment who are employees - aged 16-64',
#    'lang': 'en'}},
#  {'code': 77,
#   'description': {'value': '% of males in employment who are self employed - aged 16+',
#    'lang': 'en'}},
#  {'code': 78,
#   'description': {'value': '% of males in employment who are self employed - aged 16-64',
#    'lang': 'en'}},
#  {'code': 79,
#   'description': {'value': '% of females in employment who are employees - aged 16+',
#    'lang': 'en'}},
#  {'code': 80,
#   'description': {'value': '% of females in employment who are employees - aged 16-64',
#    'lang': 'en'}},
#  {'code': 81,
#   'description': {'value': '% of females in employment who are self employed - aged 16+',
#    'lang': 'en'}},
#  {'code': 82,
#   'description': {'value': '% of females in employment who are self employed - aged 16-64',
#    'lang': 'en'}},
#  {'code': 83,
#   'description': {'value': 'Unemployment rate - aged 16+', 'lang': 'en'}},
#  {'code': 84,
#   'description': {'value': 'Unemployment rate - aged 16-64', 'lang': 'en'}},
#  {'code': 85,
#   'description': {'value': 'Unemployment rate - aged 16-19', 'lang': 'en'}},
#  {'code': 86,
#   'description': {'value': 'Unemployment rate - aged 20-24', 'lang': 'en'}},
#  {'code': 87,
#   'description': {'value': 'Unemployment rate - aged 25-34', 'lang': 'en'}},
#  {'code': 88,
#   'description': {'value': 'Unemployment rate - aged 35-49', 'lang': 'en'}},
#  {'code': 89,
#   'description': {'value': 'Unemployment rate - aged 50+', 'lang': 'en'}},
#  {'code': 90,
#   'description': {'value': 'Unemployment rate - aged 50-64', 'lang': 'en'}},
#  {'code': 91,
#   'description': {'value': 'Unemployment rate - aged 65+', 'lang': 'en'}},
#  {'code': 92,
#   'description': {'value': 'Unemployment rate males - aged 16+',
#    'lang': 'en'}},
#  {'code': 93,
#   'description': {'value': 'Unemployment rate males - aged 16-64',
#    'lang': 'en'}},
#  {'code': 94,
#   'description': {'value': 'Unemployment rate males - aged 16-19',
#    'lang': 'en'}},
#  {'code': 95,
#   'description': {'value': 'Unemployment rate males - aged 20-24',
#    'lang': 'en'}},
#  {'code': 96,
#   'description': {'value': 'Unemployment rate males - aged 25-34',
#    'lang': 'en'}},
#  {'code': 97,
#   'description': {'value': 'Unemployment rate males - aged 35-49',
#    'lang': 'en'}},
#  {'code': 98,
#   'description': {'value': 'Unemployment rate males - aged 50+',
#    'lang': 'en'}},
#  {'code': 99,
#   'description': {'value': 'Unemployment rate males - aged 50-64',
#    'lang': 'en'}},
#  {'code': 100,
#   'description': {'value': 'Unemployment rate males - aged 65+',
#    'lang': 'en'}},
#  {'code': 101,
#   'description': {'value': 'Unemployment rate females - aged 16+',
#    'lang': 'en'}},
#  {'code': 102,
#   'description': {'value': 'Unemployment rate females - aged 16-64',
#    'lang': 'en'}},
#  {'code': 103,
#   'description': {'value': 'Unemployment rate females - aged 16-19',
#    'lang': 'en'}},
#  {'code': 104,
#   'description': {'value': 'Unemployment rate females - aged 20-24',
#    'lang': 'en'}},
#  {'code': 105,
#   'description': {'value': 'Unemployment rate females - aged 25-34',
#    'lang': 'en'}},
#  {'code': 106,
#   'description': {'value': 'Unemployment rate females - aged 35-49',
#    'lang': 'en'}},
#  {'code': 107,
#   'description': {'value': 'Unemployment rate females - aged 50+',
#    'lang': 'en'}},
#  {'code': 108,
#   'description': {'value': 'Unemployment rate females - aged 50-64',
#    'lang': 'en'}},
#  {'code': 109,
#   'description': {'value': 'Unemployment rate females - aged 65+',
#    'lang': 'en'}},
#  {'code': 110,
#   'description': {'value': '% who are economically inactive - aged 16+',
#    'lang': 'en'}},
#  {'code': 111,
#   'description': {'value': '% who are economically inactive - aged 16-64',
#    'lang': 'en'}},
#  {'code': 112,
#   'description': {'value': '% who are economically inactive - aged 16-19',
#    'lang': 'en'}},
#  {'code': 113,
#   'description': {'value': '% who are economically inactive - aged 20-24',
#    'lang': 'en'}},
#  {'code': 114,
#   'description': {'value': '% who are economically inactive - aged 25-34',
#    'lang': 'en'}},
#  {'code': 115,
#   'description': {'value': '% who are economically inactive - aged 35-49',
#    'lang': 'en'}},
#  {'code': 116,
#   'description': {'value': '% who are economically inactive - aged 50+',
#    'lang': 'en'}},
#  {'code': 117,
#   'description': {'value': '% who are economically inactive - aged 50-64',
#    'lang': 'en'}},
#  {'code': 118,
#   'description': {'value': '% who are economically inactive - aged 65+',
#    'lang': 'en'}},
#  {'code': 119,
#   'description': {'value': '% of  males who are economically inactive - aged 16+',
#    'lang': 'en'}},
#  {'code': 120,
#   'description': {'value': '% of  males who are economically inactive - aged 16-64',
#    'lang': 'en'}},
#  {'code': 121,
#   'description': {'value': '% of  males who are economically inactive - aged 16-19',
#    'lang': 'en'}},
#  {'code': 122,
#   'description': {'value': '% of  males who are economically inactive - aged 20-24',
#    'lang': 'en'}},
#  {'code': 123,
#   'description': {'value': '% of  males who are economically inactive - aged 25-34',
#    'lang': 'en'}},
#  {'code': 124,
#   'description': {'value': '% of  males who are economically inactive - aged 35-49',
#    'lang': 'en'}},
#  {'code': 125,
#   'description': {'value': '% of  males who are economically inactive - aged 50+',
#    'lang': 'en'}},
#  {'code': 126,
#   'description': {'value': '% of  males who are economically inactive - aged 50-64',
#    'lang': 'en'}},
#  {'code': 127,
#   'description': {'value': '% of  males who are economically inactive - aged 65+',
#    'lang': 'en'}},
#  {'code': 128,
#   'description': {'value': '% of females who are economically inactive - aged 16+',
#    'lang': 'en'}},
#  {'code': 129,
#   'description': {'value': '% of females who are economically inactive - aged 16-64',
#    'lang': 'en'}},
#  {'code': 130,
#   'description': {'value': '% of females who are economically inactive - aged 16-19',
#    'lang': 'en'}},
#  {'code': 131,
#   'description': {'value': '% of females who are economically inactive - aged 20-24',
#    'lang': 'en'}},
#  {'code': 132,
#   'description': {'value': '% of females who are economically inactive - aged 25-34',
#    'lang': 'en'}},
#  {'code': 133,
#   'description': {'value': '% of females who are economically inactive - aged 35-49',
#    'lang': 'en'}},
#  {'code': 134,
#   'description': {'value': '% of females who are economically inactive - aged 50+',
#    'lang': 'en'}},
#  {'code': 135,
#   'description': {'value': '% of females who are economically inactive - aged 50-64',
#    'lang': 'en'}},
#  {'code': 136,
#   'description': {'value': '% of females who are economically inactive - aged 65+',
#    'lang': 'en'}},
#  {'code': 137,
#   'description': {'value': '% aged 16-64 who are both DDA & also work-limiting disabled',
#    'lang': 'en'}},
#  {'code': 138,
#   'description': {'value': '% of males aged 16-64 who are both DDA & also work-imiting disabled',
#    'lang': 'en'}},
#  {'code': 139,
#   'description': {'value': '% of females aged 16-64 who are both DDA & also work-limiting disabled',
#    'lang': 'en'}},
#  {'code': 140,
#   'description': {'value': '% aged 16-64 who are DDA only disabled',
#    'lang': 'en'}},
#  {'code': 141,
#   'description': {'value': '% of males aged 16-64 who are DDA  only disabled',
#    'lang': 'en'}},
#  {'code': 142,
#   'description': {'value': '% of females aged 16-64 who are DDA only disabled',
#    'lang': 'en'}},
#  {'code': 143,
#   'description': {'value': '% aged 16-64 who are work-limited only disabled',
#    'lang': 'en'}},
#  {'code': 144,
#   'description': {'value': '% of males aged 16-64 who are work-limited only disabled',
#    'lang': 'en'}},
#  {'code': 145,
#   'description': {'value': '% of females aged 16-64 who are work-limited only disabled',
#    'lang': 'en'}},
#  {'code': 146,
#   'description': {'value': '% aged 16-64 who are not disabled', 'lang': 'en'}},
#  {'code': 147,
#   'description': {'value': '% of males aged 16-64 who are not disabled',
#    'lang': 'en'}},
#  {'code': 148,
#   'description': {'value': '% of females aged 16-64 who are not disabled',
#    'lang': 'en'}},
#  {'code': 149,
#   'description': {'value': 'Economic activity rate aged 16-64 - both DDA & also work-limiting',
#    'lang': 'en'}},
#  {'code': 150,
#   'description': {'value': 'Economic activity rate aged 16-64 - DDA only disabled',
#    'lang': 'en'}},
#  {'code': 151,
#   'description': {'value': 'Economic activity rate aged 16-64 - work-limiting only disabled',
#    'lang': 'en'}},
#  {'code': 152,
#   'description': {'value': 'Economic activity rate aged 16-64 - not disabled',
#    'lang': 'en'}},
#  {'code': 153,
#   'description': {'value': 'Economic activity rate males aged 16-64 - both DDA & also work-limiting',
#    'lang': 'en'}},
#  {'code': 154,
#   'description': {'value': 'Economic activity rate males aged 16-64 - DDA only disabled',
#    'lang': 'en'}},
#  {'code': 155,
#   'description': {'value': 'Economic activity rate males aged 16-64 - work-limiting only disabled',
#    'lang': 'en'}},
#  {'code': 156,
#   'description': {'value': 'Economic activity rate males aged 16-64 - not disabled',
#    'lang': 'en'}},
#  {'code': 157,
#   'description': {'value': 'Economic activity rate females aged 16-64 - both DDA & also work-limiting',
#    'lang': 'en'}},
#  {'code': 158,
#   'description': {'value': 'Economic activity rate females aged 16-64 - DDA only disabled',
#    'lang': 'en'}},
#  {'code': 159,
#   'description': {'value': 'Economic activity rate females aged 16-64 - work-limiting only disabled',
#    'lang': 'en'}},
#  {'code': 160,
#   'description': {'value': 'Economic activity rate females aged 16-64 - not disabled',
#    'lang': 'en'}},
#  {'code': 161,
#   'description': {'value': 'Employment rate aged 16-64 - both DDA & also work-limiting',
#    'lang': 'en'}},
#  {'code': 162,
#   'description': {'value': 'Employment rate aged 16-64 - DDA only disabled',
#    'lang': 'en'}},
#  {'code': 163,
#   'description': {'value': 'Employment rate aged 16-64 - work-limiting only disabled',
#    'lang': 'en'}},
#  {'code': 164,
#   'description': {'value': 'Employment rate aged 16-64 - not disabled',
#    'lang': 'en'}},
#  {'code': 165,
#   'description': {'value': 'Employment rate males aged 16-64 - both DDA & also work-limiting',
#    'lang': 'en'}},
#  {'code': 166,
#   'description': {'value': 'Employment rate males aged 16-64 - DDA only disabled',
#    'lang': 'en'}},
#  {'code': 167,
#   'description': {'value': 'Employment rate males aged 16-64 - work-limiting only disabled',
#    'lang': 'en'}},
#  {'code': 168,
#   'description': {'value': 'Employment rate males aged 16-64 - not disabled',
#    'lang': 'en'}},
#  {'code': 169,
#   'description': {'value': 'Employment rate females aged 16-64 - both DDA & also work-limiting',
#    'lang': 'en'}},
#  {'code': 170,
#   'description': {'value': 'Employment rate females aged 16-64 - DDA only disabled',
#    'lang': 'en'}},
#  {'code': 171,
#   'description': {'value': 'Employment rate females aged 16-64 - work-limiting only disabled',
#    'lang': 'en'}},
#  {'code': 172,
#   'description': {'value': 'Employment rate females aged 16-64 - not disabled',
#    'lang': 'en'}},
#  {'code': 173,
#   'description': {'value': 'Unemployment rate aged 16-64 - both DDA & also work-limiting',
#    'lang': 'en'}},
#  {'code': 174,
#   'description': {'value': 'Unemployment rate aged 16-64 - DDA only disabled',
#    'lang': 'en'}},
#  {'code': 175,
#   'description': {'value': 'Unemployment rate aged 16-64 - work-limiting only disabled',
#    'lang': 'en'}},
#  {'code': 176,
#   'description': {'value': 'Unemployment rate aged 16-64 - not disabled',
#    'lang': 'en'}},
#  {'code': 177,
#   'description': {'value': 'Unemployment rate males aged 16-64 - both DDA & also work-limiting',
#    'lang': 'en'}},
#  {'code': 178,
#   'description': {'value': 'Unemployment rate males aged 16-64 - DDA only disabled',
#    'lang': 'en'}},
#  {'code': 179,
#   'description': {'value': 'Unemployment rate males aged 16-64 - work-limiting only disabled',
#    'lang': 'en'}},
#  {'code': 180,
#   'description': {'value': 'Unemployment rate males aged 16-64 - not disabled',
#    'lang': 'en'}},
#  {'code': 181,
#   'description': {'value': 'Unemployment rate females aged 16-64 - both DDA & also work-limiting',
#    'lang': 'en'}},
#  {'code': 182,
#   'description': {'value': 'Unemployment rate females aged 16-64 - DDA only disabled',
#    'lang': 'en'}},
#  {'code': 183,
#   'description': {'value': 'Unemployment rate females aged 16-64 - work-limiting only disabled',
#    'lang': 'en'}},
#  {'code': 184,
#   'description': {'value': 'Unemployment rate females aged 16-64 - not disabled',
#    'lang': 'en'}},
#  {'code': 185,
#   'description': {'value': '% economically inactive aged 16-64 - both DDA & also work-limiting',
#    'lang': 'en'}},
#  {'code': 186,
#   'description': {'value': '% economically inactive aged 16-64 - DDA only disabled',
#    'lang': 'en'}},
#  {'code': 187,
#   'description': {'value': '% economically inactive aged 16-64 - work-limiting only disabled',
#    'lang': 'en'}},
#  {'code': 188,
#   'description': {'value': '% economically inactive aged 16-64 - not disabled',
#    'lang': 'en'}},
#  {'code': 189,
#   'description': {'value': '% economically inactive males aged 16-64 - both DDA & also work-limiting',
#    'lang': 'en'}},
#  {'code': 190,
#   'description': {'value': '% economically inactive males aged 16-64 - DDA only disabled',
#    'lang': 'en'}},
#  {'code': 191,
#   'description': {'value': '% economically inactive males aged 16-64 - work-limiting only disabled',
#    'lang': 'en'}},
#  {'code': 192,
#   'description': {'value': '% economically inactive males aged 16-64 - not disabled',
#    'lang': 'en'}},
#  {'code': 193,
#   'description': {'value': '% economically inactive females aged 16-64 - both DDA & also work-limiting',
#    'lang': 'en'}},
#  {'code': 194,
#   'description': {'value': '% economically inactive females aged 16-64 - DDA only disabled',
#    'lang': 'en'}},
#  {'code': 195,
#   'description': {'value': '% economically inactive females aged 16-64 - work-limiting only disabled',
#    'lang': 'en'}},
#  {'code': 196,
#   'description': {'value': '% economically inactive females aged 16-64 - not disabled',
#    'lang': 'en'}},
#  {'code': 197,
#   'description': {'value': '% in employment working full-time - aged 16-64',
#    'lang': 'en'}},
#  {'code': 198,
#   'description': {'value': '% in employment working full-time - aged 16-19',
#    'lang': 'en'}},
#  {'code': 199,
#   'description': {'value': '% in employment working full-time - aged 20-24',
#    'lang': 'en'}},
#  {'code': 200,
#   'description': {'value': '% in employment working full-time - aged 25-49',
#    'lang': 'en'}},
#  {'code': 201,
#   'description': {'value': '% in employment working full-time - aged 50+',
#    'lang': 'en'}},
#  {'code': 202,
#   'description': {'value': '% in employment working part-time - aged 16-64',
#    'lang': 'en'}},
#  {'code': 203,
#   'description': {'value': '% in employment working part-time - aged 16-19',
#    'lang': 'en'}},
#  {'code': 204,
#   'description': {'value': '% in employment working part-time - aged 20-24',
#    'lang': 'en'}},
#  {'code': 205,
#   'description': {'value': '% in employment working part-time - aged 25-49',
#    'lang': 'en'}},
#  {'code': 206,
#   'description': {'value': '% in employment working part-time - aged 50+',
#    'lang': 'en'}},
#  {'code': 207, 'description': {'value': 'not used 207', 'lang': 'en'}},
#  {'code': 208, 'description': {'value': 'not used 208', 'lang': 'en'}},
#  {'code': 209, 'description': {'value': 'not used 209', 'lang': 'en'}},
#  {'code': 210, 'description': {'value': 'not used 210', 'lang': 'en'}},
#  {'code': 211, 'description': {'value': 'not used 211', 'lang': 'en'}},
#  {'code': 212, 'description': {'value': 'not used 212', 'lang': 'en'}},
#  {'code': 213, 'description': {'value': 'not used 213', 'lang': 'en'}},
#  {'code': 214, 'description': {'value': 'not used 214', 'lang': 'en'}},
#  {'code': 215, 'description': {'value': 'not used 215', 'lang': 'en'}},
#  {'code': 216,
#   'description': {'value': '% all in employment who work in - A-B:agriculture and fishing (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 217,
#   'description': {'value': '% all in employment who work in - C,E:energy and water (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 218,
#   'description': {'value': '% all in employment who work in - D:manufacturing (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 219,
#   'description': {'value': '% all in employment who work in - F:construction (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 220,
#   'description': {'value': '% all in employment who work in - G-H:distribution, hotels and restaurants (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 221,
#   'description': {'value': '% all in employment who work in - I:transport and communications (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 222,
#   'description': {'value': '% all in employment who work in - J-K:banking, finance and insurance (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 223,
#   'description': {'value': '% all in employment who work in - L-N:public admin. education and health (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 224,
#   'description': {'value': '% all in employment who work in - O-Q:other services (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 225,
#   'description': {'value': '% all in employment who work in - G-Q:total services (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 226,
#   'description': {'value': '% aged 16-64 in employment who work in - A-B:agriculture and fishing (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 227,
#   'description': {'value': '% aged 16-64 in employment who work in - C,E:energy and water (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 228,
#   'description': {'value': '% aged 16-64 in employment who work in - D:manufacturing (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 229,
#   'description': {'value': '% aged 16-64 in employment who work in - F:construction (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 230,
#   'description': {'value': '% aged 16-64 in employment who work in - G-H:distribution, hotels and restaurants (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 231,
#   'description': {'value': '% aged 16-64 in employment who work in - I:transport and communications (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 232,
#   'description': {'value': '% aged 16-64 in employment who work in - J-K:banking, finance and insurance (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 233,
#   'description': {'value': '% aged 16-64 in employment who work in - L-N:public admin. education and health (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 234,
#   'description': {'value': '% aged 16-64 in employment who work in - O-Q:other services (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 235,
#   'description': {'value': '% aged 16-64 in employment who work in - G-Q:total services (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 236, 'description': {'value': 'not used 236', 'lang': 'en'}},
#  {'code': 237,
#   'description': {'value': '% aged 16-64 economically inactive who want a job',
#    'lang': 'en'}},
#  {'code': 238,
#   'description': {'value': '% aged 16-64 economically inactive who do not want a job',
#    'lang': 'en'}},
#  {'code': 239,
#   'description': {'value': '% aged 16-64 economically inactive males who want a job',
#    'lang': 'en'}},
#  {'code': 240,
#   'description': {'value': '% aged 16-64 economically inactive males who do not want a job',
#    'lang': 'en'}},
#  {'code': 241,
#   'description': {'value': '% aged 16-64 economically inactive females who want a job',
#    'lang': 'en'}},
#  {'code': 242,
#   'description': {'value': '% aged 16-64 economically inactive females who do not want a job',
#    'lang': 'en'}},
#  {'code': 243,
#   'description': {'value': '% aged 16-64 econ inact who want job reason not looking - discouraged worker',
#    'lang': 'en'}},
#  {'code': 244,
#   'description': {'value': '% aged 16-64 econ inact who want job reason not looking - long term sick',
#    'lang': 'en'}},
#  {'code': 245,
#   'description': {'value': '% aged 16-64 econ inact who want job reason not looking - looking after family/home',
#    'lang': 'en'}},
#  {'code': 246,
#   'description': {'value': '% aged 16-64 econ inact who want job reason not looking - student',
#    'lang': 'en'}},
#  {'code': 247,
#   'description': {'value': '% aged 16-64 econ inact who want job reason not looking - other',
#    'lang': 'en'}},
#  {'code': 248,
#   'description': {'value': '% aged 16-64 who are employees', 'lang': 'en'}},
#  {'code': 249,
#   'description': {'value': '% aged 16-64 who are self employed',
#    'lang': 'en'}},
#  {'code': 250,
#   'description': {'value': '% of males aged 16-64 who are employees',
#    'lang': 'en'}},
#  {'code': 251,
#   'description': {'value': '% of males aged 16-64 who are self employed',
#    'lang': 'en'}},
#  {'code': 252,
#   'description': {'value': '% of females aged 16-64 who are employees',
#    'lang': 'en'}},
#  {'code': 253,
#   'description': {'value': '% of females aged 16-64 who are self employed',
#    'lang': 'en'}},
#  {'code': 254,
#   'description': {'value': '% aged 16-64 who are economically inactive - want a job',
#    'lang': 'en'}},
#  {'code': 255,
#   'description': {'value': '% aged 16-64 who are economically inactive - do not want a job',
#    'lang': 'en'}},
#  {'code': 256,
#   'description': {'value': '% of males aged 16-64 who are economically inactive - want a job',
#    'lang': 'en'}},
#  {'code': 257,
#   'description': {'value': '% of males aged 16-64 who are economically inactive - do not want a job',
#    'lang': 'en'}},
#  {'code': 258,
#   'description': {'value': '% of females aged 16-64 who are economically inactive - want a job',
#    'lang': 'en'}},
#  {'code': 259,
#   'description': {'value': '% of females aged 16-64 who are economically inactive - do not want a job',
#    'lang': 'en'}},
#  {'code': 260,
#   'description': {'value': '% of all in employment who are Soc 2000 major group 1-3',
#    'lang': 'en'}},
#  {'code': 261,
#   'description': {'value': '% of all in employment who are Soc 2000 major group 4-5',
#    'lang': 'en'}},
#  {'code': 262,
#   'description': {'value': '% of all in employment who are Soc 2000 major group 6-7',
#    'lang': 'en'}},
#  {'code': 263,
#   'description': {'value': '% of all in employment who are Soc 2000 major group 8-9',
#    'lang': 'en'}},
#  {'code': 264,
#   'description': {'value': '% males in employment who are - 1: managers and senior officials',
#    'lang': 'en'}},
#  {'code': 265,
#   'description': {'value': '% males in employment who are - 2: professional occupations',
#    'lang': 'en'}},
#  {'code': 266,
#   'description': {'value': '% males in employment who are - 3: associate prof & tech occupations',
#    'lang': 'en'}},
#  {'code': 267,
#   'description': {'value': '% males in employment who are - 4: administrative and secretarial occupations',
#    'lang': 'en'}},
#  {'code': 268,
#   'description': {'value': '% males in employment who are - 5: skilled trades occupations',
#    'lang': 'en'}},
#  {'code': 269,
#   'description': {'value': '% males in employment who are - 6: personal service occupations',
#    'lang': 'en'}},
#  {'code': 270,
#   'description': {'value': '% males in employment who are - 7: sales and customer service occupations',
#    'lang': 'en'}},
#  {'code': 271,
#   'description': {'value': '% males in employment who are - 8: process, plant and machine operatives',
#    'lang': 'en'}},
#  {'code': 272,
#   'description': {'value': '% males in employment who are - 9: elementary occupations',
#    'lang': 'en'}},
#  {'code': 273,
#   'description': {'value': '% females in employment who are - 1: managers and senior officials',
#    'lang': 'en'}},
#  {'code': 274,
#   'description': {'value': '% females in employment who are - 2: professional occupations',
#    'lang': 'en'}},
#  {'code': 275,
#   'description': {'value': '% females in employment who are - 3: associate prof & tech occupations',
#    'lang': 'en'}},
#  {'code': 276,
#   'description': {'value': '% females in employment who are - 4: administrative and secretarial occupations',
#    'lang': 'en'}},
#  {'code': 277,
#   'description': {'value': '% females in employment who are - 5: skilled trades occupations',
#    'lang': 'en'}},
#  {'code': 278,
#   'description': {'value': '% females in employment who are - 6: personal service occupations',
#    'lang': 'en'}},
#  {'code': 279,
#   'description': {'value': '% females in employment who are - 7: sales and customer service occupations',
#    'lang': 'en'}},
#  {'code': 280,
#   'description': {'value': '% females in employment who are - 8: process, plant and machine operatives',
#    'lang': 'en'}},
#  {'code': 281,
#   'description': {'value': '% females in employment who are - 9: elementary occupations',
#    'lang': 'en'}},
#  {'code': 282, 'description': {'value': 'not used 282', 'lang': 'en'}},
#  {'code': 283, 'description': {'value': 'not used 283', 'lang': 'en'}},
#  {'code': 284, 'description': {'value': 'not used 284', 'lang': 'en'}},
#  {'code': 285, 'description': {'value': 'not used 285', 'lang': 'en'}},
#  {'code': 286, 'description': {'value': 'not used 286', 'lang': 'en'}},
#  {'code': 287, 'description': {'value': 'not used 287', 'lang': 'en'}},
#  {'code': 288, 'description': {'value': 'not used 288', 'lang': 'en'}},
#  {'code': 289, 'description': {'value': 'not used 289', 'lang': 'en'}},
#  {'code': 290,
#   'description': {'value': '% with NVQ4+ - aged 16-64', 'lang': 'en'}},
#  {'code': 291,
#   'description': {'value': '% with NVQ4+ - males aged 16-64', 'lang': 'en'}},
#  {'code': 292,
#   'description': {'value': '% with NVQ4+ - females aged 16-64', 'lang': 'en'}},
#  {'code': 293,
#   'description': {'value': '% with NVQ4+ - aged 16-19', 'lang': 'en'}},
#  {'code': 294,
#   'description': {'value': '% with NVQ4+ - aged 20-24', 'lang': 'en'}},
#  {'code': 295,
#   'description': {'value': '% with NVQ4+ - aged 25-29', 'lang': 'en'}},
#  {'code': 296,
#   'description': {'value': '% with NVQ4+ - aged 30-39', 'lang': 'en'}},
#  {'code': 297,
#   'description': {'value': '% with NVQ4+ - aged 40-49', 'lang': 'en'}},
#  {'code': 298,
#   'description': {'value': '% with NVQ4+ - aged 50-64', 'lang': 'en'}},
#  {'code': 299,
#   'description': {'value': '% with NVQ3 only - aged 16-64', 'lang': 'en'}},
#  {'code': 300,
#   'description': {'value': '% with NVQ3 only - males aged 16-64',
#    'lang': 'en'}},
#  {'code': 301,
#   'description': {'value': '% with NVQ3 only - females aged 16-64',
#    'lang': 'en'}},
#  {'code': 302,
#   'description': {'value': '% with NVQ3 only - aged 16-19', 'lang': 'en'}},
#  {'code': 303,
#   'description': {'value': '% with NVQ3 only - aged 20-24', 'lang': 'en'}},
#  {'code': 304,
#   'description': {'value': '% with NVQ3 only - aged 25-29', 'lang': 'en'}},
#  {'code': 305,
#   'description': {'value': '% with NVQ3 only - aged 30-39', 'lang': 'en'}},
#  {'code': 306,
#   'description': {'value': '% with NVQ3 only - aged 40-49', 'lang': 'en'}},
#  {'code': 307,
#   'description': {'value': '% with NVQ3 only - aged 50-64', 'lang': 'en'}},
#  {'code': 308,
#   'description': {'value': '% with Trade Apprenticeships - aged 16-64',
#    'lang': 'en'}},
#  {'code': 309,
#   'description': {'value': '% with Trade Apprenticeships - males aged 16-64',
#    'lang': 'en'}},
#  {'code': 310,
#   'description': {'value': '% with Trade Apprenticeships - females aged 16-64',
#    'lang': 'en'}},
#  {'code': 311,
#   'description': {'value': '% with Trade Apprenticeships - aged 16-19',
#    'lang': 'en'}},
#  {'code': 312,
#   'description': {'value': '% with Trade Apprenticeships - aged 20-24',
#    'lang': 'en'}},
#  {'code': 313,
#   'description': {'value': '% with Trade Apprenticeships - aged 25-29',
#    'lang': 'en'}},
#  {'code': 314,
#   'description': {'value': '% with Trade Apprenticeships - aged 30-39',
#    'lang': 'en'}},
#  {'code': 315,
#   'description': {'value': '% with Trade Apprenticeships - aged 40-49',
#    'lang': 'en'}},
#  {'code': 316,
#   'description': {'value': '% with Trade Apprenticeships - aged 50-64',
#    'lang': 'en'}},
#  {'code': 317,
#   'description': {'value': '% with NVQ2 only - aged 16-64', 'lang': 'en'}},
#  {'code': 318,
#   'description': {'value': '% with NVQ2 only - males aged 16-64',
#    'lang': 'en'}},
#  {'code': 319,
#   'description': {'value': '% with NVQ2 only - females aged 16-64',
#    'lang': 'en'}},
#  {'code': 320,
#   'description': {'value': '% with NVQ2 only - aged 16-19', 'lang': 'en'}},
#  {'code': 321,
#   'description': {'value': '% with NVQ2 only - aged 20-24', 'lang': 'en'}},
#  {'code': 322,
#   'description': {'value': '% with NVQ2 only - aged 25-29', 'lang': 'en'}},
#  {'code': 323,
#   'description': {'value': '% with NVQ2 only - aged 30-39', 'lang': 'en'}},
#  {'code': 324,
#   'description': {'value': '% with NVQ2 only - aged 40-49', 'lang': 'en'}},
#  {'code': 325,
#   'description': {'value': '% with NVQ2 only - aged 50-64', 'lang': 'en'}},
#  {'code': 326,
#   'description': {'value': '% with NVQ1 only - aged 16-64', 'lang': 'en'}},
#  {'code': 327,
#   'description': {'value': '% with NVQ1 only - males aged 16-64',
#    'lang': 'en'}},
#  {'code': 328,
#   'description': {'value': '% with NVQ1 only - females aged 16-64',
#    'lang': 'en'}},
#  {'code': 329,
#   'description': {'value': '% with NVQ1 only - aged 16-19', 'lang': 'en'}},
#  {'code': 330,
#   'description': {'value': '% with NVQ1 only - aged 20-24', 'lang': 'en'}},
#  {'code': 331,
#   'description': {'value': '% with NVQ1 only - aged 25-29', 'lang': 'en'}},
#  {'code': 332,
#   'description': {'value': '% with NVQ1 only - aged 30-39', 'lang': 'en'}},
#  {'code': 333,
#   'description': {'value': '% with NVQ1 only - aged 40-49', 'lang': 'en'}},
#  {'code': 334,
#   'description': {'value': '% with NVQ1 only - aged 50-64', 'lang': 'en'}},
#  {'code': 335,
#   'description': {'value': '% with other qualifications (NVQ) - aged 16-64',
#    'lang': 'en'}},
#  {'code': 336,
#   'description': {'value': '% with other qualifications (NVQ) - males aged 16-64',
#    'lang': 'en'}},
#  {'code': 337,
#   'description': {'value': '% with other qualifications (NVQ) - females aged 16-64',
#    'lang': 'en'}},
#  {'code': 338,
#   'description': {'value': '% with other qualifications (NVQ) - aged 16-19',
#    'lang': 'en'}},
#  {'code': 339,
#   'description': {'value': '% with other qualifications (NVQ) - aged 20-24',
#    'lang': 'en'}},
#  {'code': 340,
#   'description': {'value': '% with other qualifications (NVQ) - aged 25-29',
#    'lang': 'en'}},
#  {'code': 341,
#   'description': {'value': '% with other qualifications (NVQ) - aged 30-39',
#    'lang': 'en'}},
#  {'code': 342,
#   'description': {'value': '% with other qualifications (NVQ) - aged 40-49',
#    'lang': 'en'}},
#  {'code': 343,
#   'description': {'value': '% with other qualifications (NVQ) - aged 50-64',
#    'lang': 'en'}},
#  {'code': 344,
#   'description': {'value': '% with no qualifications (NVQ) - aged 16-64',
#    'lang': 'en'}},
#  {'code': 345,
#   'description': {'value': '% with no qualifications (NVQ) - males aged 16-64',
#    'lang': 'en'}},
#  {'code': 346,
#   'description': {'value': '% with no qualifications (NVQ) - females aged 16-64',
#    'lang': 'en'}},
#  {'code': 347,
#   'description': {'value': '% with no qualifications (NVQ) - aged 16-19',
#    'lang': 'en'}},
#  {'code': 348,
#   'description': {'value': '% with no qualifications (NVQ) - aged 20-24',
#    'lang': 'en'}},
#  {'code': 349,
#   'description': {'value': '% with no qualifications (NVQ) - aged 25-29',
#    'lang': 'en'}},
#  {'code': 350,
#   'description': {'value': '% with no qualifications (NVQ) - aged 30-39',
#    'lang': 'en'}},
#  {'code': 351,
#   'description': {'value': '% with no qualifications (NVQ) - aged 40-49',
#    'lang': 'en'}},
#  {'code': 352,
#   'description': {'value': '% with no qualifications (NVQ) - aged 50-64',
#    'lang': 'en'}},
#  {'code': 353,
#   'description': {'value': '% of economically active with NVQ4+ - aged 16-64',
#    'lang': 'en'}},
#  {'code': 354,
#   'description': {'value': '% of economically active with NVQ4+ - males aged 16-64',
#    'lang': 'en'}},
#  {'code': 355,
#   'description': {'value': '% of economically active with NVQ4+ - females aged 16-64',
#    'lang': 'en'}},
#  {'code': 356,
#   'description': {'value': '% of economically active with NVQ4+ - aged 16-19',
#    'lang': 'en'}},
#  {'code': 357,
#   'description': {'value': '% of economically active with NVQ4+ - aged 20-24',
#    'lang': 'en'}},
#  {'code': 358,
#   'description': {'value': '% of economically active with NVQ4+ - aged 25-29',
#    'lang': 'en'}},
#  {'code': 359,
#   'description': {'value': '% of economically active with NVQ4+ - aged 30-39',
#    'lang': 'en'}},
#  {'code': 360,
#   'description': {'value': '% of economically active with NVQ4+ - aged 40-49',
#    'lang': 'en'}},
#  {'code': 361,
#   'description': {'value': '% of economically active with NVQ4+ - aged 50-64',
#    'lang': 'en'}},
#  {'code': 362,
#   'description': {'value': '% of economically active with NVQ3 only - aged 16-64',
#    'lang': 'en'}},
#  {'code': 363,
#   'description': {'value': '% of economically active with NVQ3 only - males aged 16-64',
#    'lang': 'en'}},
#  {'code': 364,
#   'description': {'value': '% of economically active with NVQ3 only - females aged 16-64',
#    'lang': 'en'}},
#  {'code': 365,
#   'description': {'value': '% of economically active with NVQ3 only - aged 16-19',
#    'lang': 'en'}},
#  {'code': 366,
#   'description': {'value': '% of economically active with NVQ3 only - aged 20-24',
#    'lang': 'en'}},
#  {'code': 367,
#   'description': {'value': '% of economically active with NVQ3 only - aged 25-29',
#    'lang': 'en'}},
#  {'code': 368,
#   'description': {'value': '% of economically active with NVQ3 only - aged 30-39',
#    'lang': 'en'}},
#  {'code': 369,
#   'description': {'value': '% of economically active with NVQ3 only - aged 40-49',
#    'lang': 'en'}},
#  {'code': 370,
#   'description': {'value': '% of economically active with NVQ3 only - aged 50-64',
#    'lang': 'en'}},
#  {'code': 371,
#   'description': {'value': '% of economically active with Trade Apprenticeships - aged 16-64',
#    'lang': 'en'}},
#  {'code': 372,
#   'description': {'value': '% of economically active with Trade Apprenticeships - males aged 16-64',
#    'lang': 'en'}},
#  {'code': 373,
#   'description': {'value': '% of economically active with Trade Apprenticeships - females aged 16-64',
#    'lang': 'en'}},
#  {'code': 374,
#   'description': {'value': '% of economically active with Trade Apprenticeships - aged 16-19',
#    'lang': 'en'}},
#  {'code': 375,
#   'description': {'value': '% of economically active with Trade Apprenticeships - aged 20-24',
#    'lang': 'en'}},
#  {'code': 376,
#   'description': {'value': '% of economically active with Trade Apprenticeships - aged 25-29',
#    'lang': 'en'}},
#  {'code': 377,
#   'description': {'value': '% of economically active with Trade Apprenticeships - aged 30-39',
#    'lang': 'en'}},
#  {'code': 378,
#   'description': {'value': '% of economically active with Trade Apprenticeships - aged 40-49',
#    'lang': 'en'}},
#  {'code': 379,
#   'description': {'value': '% of economically active with Trade Apprenticeships - aged 50-64',
#    'lang': 'en'}},
#  {'code': 380,
#   'description': {'value': '% of economically active with NVQ2 only - aged 16-64',
#    'lang': 'en'}},
#  {'code': 381,
#   'description': {'value': '% of economically active with NVQ2 only - males aged 16-64',
#    'lang': 'en'}},
#  {'code': 382,
#   'description': {'value': '% of economically active with NVQ2 only - females aged 16-64',
#    'lang': 'en'}},
#  {'code': 383,
#   'description': {'value': '% of economically active with NVQ2 only - aged 16-19',
#    'lang': 'en'}},
#  {'code': 384,
#   'description': {'value': '% of economically active with NVQ2 only - aged 20-24',
#    'lang': 'en'}},
#  {'code': 385,
#   'description': {'value': '% of economically active with NVQ2 only - aged 25-29',
#    'lang': 'en'}},
#  {'code': 386,
#   'description': {'value': '% of economically active with NVQ2 only - aged 30-39',
#    'lang': 'en'}},
#  {'code': 387,
#   'description': {'value': '% of economically active with NVQ2 only - aged 40-49',
#    'lang': 'en'}},
#  {'code': 388,
#   'description': {'value': '% of economically active with NVQ2 only - aged 50-64',
#    'lang': 'en'}},
#  {'code': 389,
#   'description': {'value': '% of economically active with NVQ1 only - aged 16-64',
#    'lang': 'en'}},
#  {'code': 390,
#   'description': {'value': '% of economically active with NVQ1 only - males aged 16-64',
#    'lang': 'en'}},
#  {'code': 391,
#   'description': {'value': '% of economically active with NVQ1 only - females aged 16-64',
#    'lang': 'en'}},
#  {'code': 392,
#   'description': {'value': '% of economically active with NVQ1 only - aged 16-19',
#    'lang': 'en'}},
#  {'code': 393,
#   'description': {'value': '% of economically active with NVQ1 only - aged 20-24',
#    'lang': 'en'}},
#  {'code': 394,
#   'description': {'value': '% of economically active with NVQ1 only - aged 25-29',
#    'lang': 'en'}},
#  {'code': 395,
#   'description': {'value': '% of economically active with NVQ1 only - aged 30-39',
#    'lang': 'en'}},
#  {'code': 396,
#   'description': {'value': '% of economically active with NVQ1 only - aged 40-49',
#    'lang': 'en'}},
#  {'code': 397,
#   'description': {'value': '% of economically active with NVQ1 only - aged 50-64',
#    'lang': 'en'}},
#  {'code': 398,
#   'description': {'value': '% of economically active with other qualifications (NVQ) - aged 16-64',
#    'lang': 'en'}},
#  {'code': 399,
#   'description': {'value': '% of economically active with other qualifications (NVQ) - males aged 16-64',
#    'lang': 'en'}},
#  {'code': 400,
#   'description': {'value': '% of economically active with other qualifications (NVQ) - females aged 16-64',
#    'lang': 'en'}},
#  {'code': 401,
#   'description': {'value': '% of economically active with other qualifications (NVQ) - aged 16-19',
#    'lang': 'en'}},
#  {'code': 402,
#   'description': {'value': '% of economically active with other qualifications (NVQ) - aged 20-24',
#    'lang': 'en'}},
#  {'code': 403,
#   'description': {'value': '% of economically active with other qualifications (NVQ) - aged 25-29',
#    'lang': 'en'}},
#  {'code': 404,
#   'description': {'value': '% of economically active with other qualifications (NVQ) - aged 30-39',
#    'lang': 'en'}},
#  {'code': 405,
#   'description': {'value': '% of economically active with other qualifications (NVQ) - aged 40-49',
#    'lang': 'en'}},
#  {'code': 406,
#   'description': {'value': '% of economically active with other qualifications (NVQ) - aged 50-64',
#    'lang': 'en'}},
#  {'code': 407,
#   'description': {'value': '% of economically active with no qualifications (NVQ) - aged 16-64',
#    'lang': 'en'}},
#  {'code': 408,
#   'description': {'value': '% of economically active with no qualifications (NVQ) - males aged 16-64',
#    'lang': 'en'}},
#  {'code': 409,
#   'description': {'value': '% of economically active with no qualifications (NVQ) - females aged 16-64',
#    'lang': 'en'}},
#  {'code': 410,
#   'description': {'value': '% of economically active with no qualifications (NVQ) - aged 16-19',
#    'lang': 'en'}},
#  {'code': 411,
#   'description': {'value': '% of economically active with no qualifications (NVQ) - aged 20-24',
#    'lang': 'en'}},
#  {'code': 412,
#   'description': {'value': '% of economically active with no qualifications (NVQ) - aged 25-29',
#    'lang': 'en'}},
#  {'code': 413,
#   'description': {'value': '% of economically active with no qualifications (NVQ) - aged 30-39',
#    'lang': 'en'}},
#  {'code': 414,
#   'description': {'value': '% of economically active with no qualifications (NVQ) - aged 40-49',
#    'lang': 'en'}},
#  {'code': 415,
#   'description': {'value': '% of economically active with no qualifications (NVQ) - aged 50-64',
#    'lang': 'en'}},
#  {'code': 416,
#   'description': {'value': '% of all who received job related training in last  4 wks - aged 16-64',
#    'lang': 'en'}},
#  {'code': 417,
#   'description': {'value': '% of all who received job related training in last  4 wks - aged 25-64',
#    'lang': 'en'}},
#  {'code': 418,
#   'description': {'value': '% all who received job rel. train in last 4 wks -employees & self emp. aged 16-64',
#    'lang': 'en'}},
#  {'code': 419,
#   'description': {'value': '% all who received job related training in last  4 wks - in managerial and prof. occs',
#    'lang': 'en'}},
#  {'code': 420,
#   'description': {'value': '% all who received job related training in last  4 wks - in service industries (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 421,
#   'description': {'value': '% males who received job related training in last 4 wks - aged 16-64',
#    'lang': 'en'}},
#  {'code': 422,
#   'description': {'value': '% males who received job related training in last 4 wks - aged 25-64',
#    'lang': 'en'}},
#  {'code': 423,
#   'description': {'value': '% males who received job rel. train. in last 4 wks - employees & self emp. aged 16-64',
#    'lang': 'en'}},
#  {'code': 424,
#   'description': {'value': '% males who received job rel. train. in last 4 wks - in managerial & prof. occs.',
#    'lang': 'en'}},
#  {'code': 425,
#   'description': {'value': '% males who received job rel. train. in last 4 wks - in service industries (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 426,
#   'description': {'value': '% females who received job rel. train. in last 4 wks - aged 16-64',
#    'lang': 'en'}},
#  {'code': 427,
#   'description': {'value': '% females who received job rel. train. in last 4 wks - aged 25-64',
# ...
#    'lang': 'en'}},
#  {'code': 894,
#   'description': {'value': 'Unemployment rate  - aged 16+ white not UK national',
#    'lang': 'en'}},
#  {'code': 895,
#   'description': {'value': 'Unemployment rate  - aged 16+ ethnic minority UK national',
#    'lang': 'en'}},
#  {'code': 896,
#   'description': {'value': 'Unemployment rate  - aged 16+ ethnic minority not UK national',
#    'lang': 'en'}},
#  {'code': 897,
#   'description': {'value': 'Economic inactivity rate - aged 16-64 white UK national',
#    'lang': 'en'}},
#  {'code': 898,
#   'description': {'value': 'Economic inactivity rate - aged 16-64 white not UK national',
#    'lang': 'en'}},
#  {'code': 899,
#   'description': {'value': 'Economic inactivity rate - aged 16-64 ethnic minority UK national',
#    'lang': 'en'}},
#  {'code': 900,
#   'description': {'value': 'Economic inactivity rate - aged 16-64 ethnic minority not UK national',
#    'lang': 'en'}},
#  {'code': 901,
#   'description': {'value': '% 16+ employed in A-B:agriculture and fishing (SIC 92/03) who are white',
#    'lang': 'en'}},
#  {'code': 902,
#   'description': {'value': '% 16+ employed in C,E:energy and water (SIC 92/03) who are white',
#    'lang': 'en'}},
#  {'code': 903,
#   'description': {'value': '% 16+ employed in D:manufacturing (SIC 92/03) who are white',
#    'lang': 'en'}},
#  {'code': 904,
#   'description': {'value': '% 16+ employed in F:construction (SIC 92/03) who are white',
#    'lang': 'en'}},
#  {'code': 905,
#   'description': {'value': '% 16+ employed in G-H:distribution, hotels and restaurants (SIC 92/03) who are white',
#    'lang': 'en'}},
#  {'code': 906,
#   'description': {'value': '% 16+ employed in I:transport and communication (SIC 92/03) who are white',
#    'lang': 'en'}},
#  {'code': 907,
#   'description': {'value': '% 16+ employed in J-K:banking, finance and insurance (SIC 92/03) who are white',
#    'lang': 'en'}},
#  {'code': 908,
#   'description': {'value': '% 16+ employed in L-N:public administration, education and health (SIC 92/03) who are white',
#    'lang': 'en'}},
#  {'code': 909,
#   'description': {'value': '% 16+ employed in O-Q:other services (SIC 92/03) who are white',
#    'lang': 'en'}},
#  {'code': 910,
#   'description': {'value': '% 16+ employed in G-Q:total services (SIC 92/03) who are white',
#    'lang': 'en'}},
#  {'code': 911,
#   'description': {'value': '% 16+ employed in A-B:agriculture and fishing (SIC 92/03) who are ethnic minority',
#    'lang': 'en'}},
#  {'code': 912,
#   'description': {'value': '% 16+ employed in C,E:energy and water (SIC 92/03) who are ethnic minority',
#    'lang': 'en'}},
#  {'code': 913,
#   'description': {'value': '% 16+ employed in D:manufacturing (SIC 92/03) who are ethnic minority',
#    'lang': 'en'}},
#  {'code': 914,
#   'description': {'value': '% 16+ employed in F:construction (SIC 92/03) who are ethnic minority',
#    'lang': 'en'}},
#  {'code': 915,
#   'description': {'value': '% 16+ employed in G-H:distribution, hotels and restaurants (SIC 92/03) who are ethnic minority',
#    'lang': 'en'}},
#  {'code': 916,
#   'description': {'value': '% 16+ employed in I:transport and communication (SIC 92/03) who are ethnic minority',
#    'lang': 'en'}},
#  {'code': 917,
#   'description': {'value': '% 16+ employed in J-K:banking, finance and insurance (SIC 92/03) who are ethnic minority',
#    'lang': 'en'}},
#  {'code': 918,
#   'description': {'value': '% 16+ employed in L-N:public administration, education and health (SIC 92/03) who are ethnic minority',
#    'lang': 'en'}},
#  {'code': 919,
#   'description': {'value': '% 16+ employed in O-Q:other services (SIC 92/03) who are ethnic minority',
#    'lang': 'en'}},
#  {'code': 920,
#   'description': {'value': '% 16+ employed in G-Q:total services (SIC 92/03) who are ethnic minority',
#    'lang': 'en'}},
#  {'code': 921,
#   'description': {'value': '% 16+ whites in employment who are employed in A-B:agriculture and fishing (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 922,
#   'description': {'value': '% 16+ whites in employment who are employed in C,E:energy and water (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 923,
#   'description': {'value': '% 16+ whites in employment who are employed in D:manufacturing (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 924,
#   'description': {'value': '% 16+ whites in employment who are employed in F:construction (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 925,
#   'description': {'value': '% 16+ whites in employment who are employed in G-H:distribution hotels and restaurants (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 926,
#   'description': {'value': '% 16+ whites in employment who are employed in I:transport and communication (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 927,
#   'description': {'value': '% 16+ whites in employment who are employed in J-K:banking, finance and insurance (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 928,
#   'description': {'value': '% 16+ whites in employment who are employed in L-N:public admin, education and health (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 929,
#   'description': {'value': '% 16+ whites in employment who are employed in O-Q:other services (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 930,
#   'description': {'value': '% 16+ whites in employment who are employed in G-Q:total services (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 931,
#   'description': {'value': '% 16+ ethnic minority in employment who are employed in A-B:agriculture and fishing (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 932,
#   'description': {'value': '% 16+ ethnic minority in employment who are employed in C,E:energy and water (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 933,
#   'description': {'value': '% 16+ ethnic minority in employment who are employed in D:manufacturing (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 934,
#   'description': {'value': '% 16+ ethnic minority in employment who are employed in F:construction (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 935,
#   'description': {'value': '% 16+ ethnic minority in employment who are employed in G-H:distribution hotels & restaurants (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 936,
#   'description': {'value': '% 16+ ethnic minority in employment who are employed in I:transport & comms. (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 937,
#   'description': {'value': '% 16+ ethnic minority in employment who are employed in J-K:banking, finance & insurance (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 938,
#   'description': {'value': '% 16+ ethnic minority in employment who are employed in L-N:public admin, education & health (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 939,
#   'description': {'value': '% 16+ ethnic minority in employment who are employed in O-Q:other services (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 940,
#   'description': {'value': '% 16+ ethnic minority in employment who are employed in G-Q:total services (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 941,
#   'description': {'value': '% 16+ mixed ethnic groups in employment who are employed in A-B:agriculture & fishing (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 942,
#   'description': {'value': '% 16+ mixed ethnic groups in employment who are employed in C,E:energy & water (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 943,
#   'description': {'value': '% 16+ mixed ethnic groups in employment who are employed in D:manufacturing (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 944,
#   'description': {'value': '% 16+ mixed ethnic groups in employment who are employed in F:construction (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 945,
#   'description': {'value': '% 16+ mixed ethnic groups in employment who are employed in G-H:distn. hotels & rests (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 946,
#   'description': {'value': '% 16+ mixed ethnic groups in employment who are employed in I:transport & comms. (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 947,
#   'description': {'value': '% 16+ mixed ethnic groups in employment who are employed in J-K:banking, finance & insur. (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 948,
#   'description': {'value': '% 16+ mixed ethnic groups in employment who are employed in L-N:pub. admin, educ. & health (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 949,
#   'description': {'value': '% 16+ mixed ethnic groups in employment who are employed in O-Q:other services (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 950,
#   'description': {'value': '% 16+ mixed ethnic groups in employment who are employed in G-Q:total services (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 951,
#   'description': {'value': '% 16+ Indians in employment who are employed in A-B:agriculture & fishing (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 952,
#   'description': {'value': '% 16+ Indians in employment who are employed in C,E:energy & water (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 953,
#   'description': {'value': '% 16+ Indians in employment who are employed in D:manufacturing (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 954,
#   'description': {'value': '% 16+ Indians in employment who are employed in F:construction (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 955,
#   'description': {'value': '% 16+ Indians in employment who are employed in G-H:distribution hotels & restaurants (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 956,
#   'description': {'value': '% 16+ Indians in employment who are employed in I:transport & comms. (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 957,
#   'description': {'value': '%  16+ Indians in employment who are employed in J-K:banking, finance & insurance (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 958,
#   'description': {'value': '% 16+ Indians in employment who are employed in L-N:public admin, education & health (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 959,
#   'description': {'value': '% 16+ Indians in employment who are employed in O-Q:other services (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 960,
#   'description': {'value': '% 16+ Indians in employment who are employed in G-Q:total services (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 961,
#   'description': {'value': '% 16+ Pakistani/Bangladeshis in employment who are employed in A-B:agriculture & fishing (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 962,
#   'description': {'value': '% 16+ Pakistani/Bangladeshis in employment who are employed in C,E:energy & water (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 963,
#   'description': {'value': '% 16+ Pakistani/Bangladeshis in employment who are employed in D:manufacturing (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 964,
#   'description': {'value': '% 16+ Pakistani/Bangladeshis in employment who are employed in F:construction (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 965,
#   'description': {'value': '% 16+ Pakistani/Bangladeshis in employment who are employed in G-H:distn. hotels & rests (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 966,
#   'description': {'value': '% 16+ Pakistani/Bangladeshis in employment who are employed in I:transport & comms. (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 967,
#   'description': {'value': '% 16+ Pakistani/Bangladeshis in employment who are employed in J-K:banks, finance & insu. (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 968,
#   'description': {'value': '% 16+ Pakistani/Bangladeshis in employment who are employed in L-N:pub. admin, educ. & health (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 969,
#   'description': {'value': '% 16+ Pakistani/Bangladeshis in employment who are employed in O-Q:other services (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 970,
#   'description': {'value': '% 16+ Pakistani/Bangladeshis in employment who are employed in G-Q:total services (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 971,
#   'description': {'value': '% 16+ Black or Black British in employment who are employed in A-B:agriculture & fishing (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 972,
#   'description': {'value': '% 16+ Black or Black British in employment who are  employed in C,E:energy & water (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 973,
#   'description': {'value': '% 16+ Black or Black British in employment who are employed in D:manufacturing (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 974,
#   'description': {'value': '% 16+ Black or Black British in employment who are employed in F:construction (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 975,
#   'description': {'value': '% 16+ Black or Black British in employment who are employed in G-H:distn hotels & rests (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 976,
#   'description': {'value': '% 16+ Black or Black British in employment who are employed in I:transport & comms. (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 977,
#   'description': {'value': '% 16+ Black or Black British in employment who are employed in J-K:banks, finance & insu. (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 978,
#   'description': {'value': '% 16+ Black or Black British in employment who are employed in L-N:pub. admin, educ. & health (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 979,
#   'description': {'value': '% 16+ Black or Black British in employment who are employed in O-Q:other services (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 980,
#   'description': {'value': '% 16+ Black or Black British in employment who are employed in G-Q:total services (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 981,
#   'description': {'value': '% 16+ other ethnic grps in employment who are employed in A-B:agriculture & fishing (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 982,
#   'description': {'value': '% 16+ other ethnic grps in employment who are employed in C,E:energy & water (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 983,
#   'description': {'value': '% 16+ other ethnic grps in employment who are employed in D:manufacturing (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 984,
#   'description': {'value': '% 16+ other ethnic grps in employment who are employed in F:construction (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 985,
#   'description': {'value': '% 16+ other ethnic grps in employment who are employed in G-H:distn. hotels & rests. (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 986,
#   'description': {'value': '% 16+ other ethnic grps in employment who are employed in I:transport & comms. (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 987,
#   'description': {'value': '% 16+ other ethnic grps in employment who are employed in J-K:banking, finance & ins. (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 988,
#   'description': {'value': '% 16+ other ethnic grps in employment who are employed in L-N:pub. admin, educ. & health (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 989,
#   'description': {'value': '% 16+ other ethnic grps in employment who are employed in O-Q:other services (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 990,
#   'description': {'value': '% 16+ other ethnic grps in employment who are employed in G-Q:total services (SIC 92/03)',
#    'lang': 'en'}},
#  {'code': 991,
#   'description': {'value': '% 16+ employed as managers & senior officials who are white (SOC2020)',
#    'lang': 'en'}},
#  {'code': 992,
#   'description': {'value': '% 16+ employed in pressionals occupations who are white (SOC2020)',
#    'lang': 'en'}},
#  {'code': 993,
#   'description': {'value': '% 16+ employed  in associate pressional & technical occupations who are white (SOC2020)',
#    'lang': 'en'}},
#  {'code': 994,
#   'description': {'value': '% 16+ employed in administrative & secretarial occupations who are white (SOC2020)',
#    'lang': 'en'}},
#  {'code': 995,
#   'description': {'value': '% 16+ employed in skilled trades occupations who are white (SOC2020)',
#    'lang': 'en'}},
#  {'code': 996,
#   'description': {'value': '% 16+ employed in personal service occupations who are white (SOC2020)',
#    'lang': 'en'}},
#  {'code': 997,
#   'description': {'value': '% 16+ employed in sales & consumer service who are white occupations (SOC2020)',
#    'lang': 'en'}},
#  {'code': 998,
#   'description': {'value': '% 16+ employed as process, plant & machine operatives who are white (SOC2020)',
#    'lang': 'en'}},
#  {'code': 999,
#   'description': {'value': '% 16+ employed in elementary occupations who are white (SOC2020)',
#    'lang': 'en'}},
#  {'code': 1000,
#   'description': {'value': '% 16+ employed as managers & senior officials who are ethnic minority (SOC2020)',
#    'lang': 'en'}},
#  ...]

# %%
dimension
# Out:
# {'codelist': 'CL_17_5_GEOGRAPHY', 'conceptref': 'GEOGRAPHY'}

# %%
dimensions
# Out:
# [{'codelist': 'CL_17_5_GEOGRAPHY', 'conceptref': 'GEOGRAPHY'},
#  {'codelist': 'CL_17_5_VARIABLE', 'conceptref': 'VARIABLE'},
#  {'codelist': 'CL_17_5_MEASURES', 'conceptref': 'MEASURES'},
#  {'codelist': 'CL_17_5_FREQ',
#   'conceptref': 'FREQ',
#   'isfrequencydimension': 'true'}]

# %%
dimension_values
# Out:
# [{'code': 'Q', 'description': {'value': 'Quarterly', 'lang': 'en'}},
#  {'code': 'S',
#   'description': {'value': 'Half-yearly, semester', 'lang': 'en'}},
#  {'code': 'A', 'description': {'value': 'Annually', 'lang': 'en'}}]

# %%
data['structure']['keyfamilies']['keyfamily'][0]['components']['dimension']
# Out:
# [{'codelist': 'CL_17_5_GEOGRAPHY', 'conceptref': 'GEOGRAPHY'},
#  {'codelist': 'CL_17_5_VARIABLE', 'conceptref': 'VARIABLE'},
#  {'codelist': 'CL_17_5_MEASURES', 'conceptref': 'MEASURES'},
#  {'codelist': 'CL_17_5_FREQ',
#   'conceptref': 'FREQ',
#   'isfrequencydimension': 'true'}]
